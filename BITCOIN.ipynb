# %%
# !pip install requests
# !pip install bs4
# !pip install html5lib

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://live.blockcypher.com/btc-testnet/"
r = requests.get(url)

# %%
html_Content = r.content

# %%
soup = BeautifulSoup(html_Content, 'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="" name="description"/>
# <meta content="" name="author"/>
# <link href="/static/img/favicon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/static/img/favicon-160x160.png" rel="icon" sizes="160x160" type="image/png"/>
# <link href="/static/img/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/static/img/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/static/img/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <title>
#
#
#     Bitcoin Testnet Block Explorer
#
#
#       | BlockCypher
#     </title>
# <link href="//fonts.googleapis.com/css?family=Raleway:300" rel="stylesheet" type="text/css"/>
# ...

# %%
div_tags = soup.find_all('div', id ="newtx-section", )
print(div_tags)
# Out:
# [<div id="newtx-section">
# <h2>Latest Transactions</h2>
# <div class="table-responsive">
# <table class="table">
# <tr id="latest-txs">
# <th>Transaction Hash</th>
# <th>BTC</th>
# <th>Time</th>
# <th>Miner Preference</th>
# </tr>
# <tr class="new-tx" style="display;none">
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="new-tx">
# <td>
# <a href="/btc-testnet/tx/e01c20aa738020f353fa4c79e965863cdc6b39b2b835ce16b8228feb850e9c13/">
# e01c20aa7380
# </a>
# ...
# </td>
# <td>
# 0.00178596 BTC
# </td>
# <td>
# <time class="timeago" datetime="2022-07-02T10:20:04Z">
# 2022-07-02 10:20 GMT
# </time>
# </td>
# <td>
# low
# </td>
# </tr>
# <tr class="new-tx">
# <td>
# <a href="/btc-testnet/tx/f093e834796d3e6fa9271eb1dc6623a18cad2a39fcbff922a685880796787ff7/">
# f093e834796d
# </a>
# ...
# </td>
# <td>
# 0.00430288 BTC
# </td>
# <td>
# <time class="timeago" datetime="2022-07-02T10:20:02Z">
# 2022-07-02 10:20 GMT
# </time>
# </td>
# <td>
# low
# </td>
# </tr>
# ...

# %%
print(len(table))
# Out:
# 1

# %%
td_tags = soup.find(id="newtx-section").find_all("td")
print(td_tags)
print(len(td_tags))
# Out:
# [<td></td>, <td></td>, <td></td>, <td></td>, <td>
# <a href="/btc-testnet/tx/e01c20aa738020f353fa4c79e965863cdc6b39b2b835ce16b8228feb850e9c13/">
# e01c20aa7380
# </a>
# ...
# </td>, <td>
# 0.00178596 BTC
# </td>, <td>
# <time class="timeago" datetime="2022-07-02T10:20:04Z">
# 2022-07-02 10:20 GMT
# </time>
# </td>, <td>
# low
# </td>, <td>
# <a href="/btc-testnet/tx/f093e834796d3e6fa9271eb1dc6623a18cad2a39fcbff922a685880796787ff7/">
# f093e834796d
# </a>
# ...
# </td>, <td>
# 0.00430288 BTC
# </td>, <td>
# <time class="timeago" datetime="2022-07-02T10:20:02Z">
# 2022-07-02 10:20 GMT
# </time>
# </td>, <td>
# low
# </td>, <td>
# <a href="/btc-testnet/tx/e9bee437bc2859eac01ea8f62ecf093c8efe776b0322070e229b626cc2019157/">
# e9bee437bc28
# </a>
# ...
# </td>, <td>
# 0.0086554 BTC
# </td>, <td>
# <time class="timeago" datetime="2022-07-02T09:58:25Z">
# 2022-07-02 09:58 GMT
# </time>
# </td>, <td>
# medium
# </td>, <td>
# ...

# %%
tr_tags = soup.find_all('tr', )
print(tr_tags)
print(len(tr_tags))
# Out:
# [<tr>
# <th>Height</th>
# <th>Age</th>
# <th>Transactions</th>
# <th>Total Sent</th>
# <th>Total Fees</th>
# <th>Block Size (in bytes)</th>
# </tr>, <tr>
# <td>
# <a href="/btc-testnet/block/2283527/">2283527</a>
# </td>
# <td>2022-07-01T07:27:14.719Z</td>
# <td>8</td>
# <td>18.611 BTC</td>
# <td>0.0 BTC</td>
# <td>4,713</td>
# </tr>, <tr>
# <td>
# <a href="/btc-testnet/block/2283526/">2283526</a>
# </td>
# <td>2022-07-01T07:23:31.999Z</td>
# <td>7</td>
# <td>18.482 BTC</td>
# <td>0.0 BTC</td>
# <td>4,414</td>
# </tr>, <tr>
# <td>
# <a href="/btc-testnet/block/2283525/">2283525</a>
# </td>
# <td>2022-07-01T07:23:25.175Z</td>
# <td>1</td>
# <td>0.0 BTC</td>
# <td>0.0 BTC</td>
# <td>271</td>
# </tr>, <tr>
# <td>
# <a href="/btc-testnet/block/2283524/">2283524</a>
# </td>
# <td>2022-07-01T07:22:54.816Z</td>
# <td>26</td>
# <td>28.283 BTC</td>
# <td>0.001 BTC</td>
# <td>52,593</td>
# </tr>, <tr>
# <td>
# <a href="/btc-testnet/block/2283523/">2283523</a>
# </td>
# ...

# %%
all_data = {"Td Tags":td_tags, "Tr Tags": tr_tags}
print(all_data)
# Out:
# {'Td Tags': [<td></td>, <td></td>, <td></td>, <td></td>, <td>
# <a href="/btc-testnet/tx/e01c20aa738020f353fa4c79e965863cdc6b39b2b835ce16b8228feb850e9c13/">
# e01c20aa7380
# </a>
# ...
# </td>, <td>
# 0.00178596 BTC
# </td>, <td>
# <time class="timeago" datetime="2022-07-02T10:20:04Z">
# 2022-07-02 10:20 GMT
# </time>
# </td>, <td>
# low
# </td>, <td>
# <a href="/btc-testnet/tx/f093e834796d3e6fa9271eb1dc6623a18cad2a39fcbff922a685880796787ff7/">
# f093e834796d
# </a>
# ...
# </td>, <td>
# 0.00430288 BTC
# </td>, <td>
# <time class="timeago" datetime="2022-07-02T10:20:02Z">
# 2022-07-02 10:20 GMT
# </time>
# </td>, <td>
# low
# </td>, <td>
# <a href="/btc-testnet/tx/e9bee437bc2859eac01ea8f62ecf093c8efe776b0322070e229b626cc2019157/">
# e9bee437bc28
# </a>
# ...
# </td>, <td>
# 0.0086554 BTC
# </td>, <td>
# <time class="timeago" datetime="2022-07-02T09:58:25Z">
# 2022-07-02 09:58 GMT
# </time>
# </td>, <td>
# medium
# </td>, <td>
# ...

# %%
print(len(td_tags))
print(len(tr_tags))
# Out:
# 32
# 17

# %%
arr = [tr_tags, td_tags]
df = pd.DataFrame(arr)
df
# Out:
#                                                   0   \
# 0  [\n, [Height], \n, [Age], \n, [Transactions], ...
# 1                                                 []
#
#                                                   1   \
# 0  [\n, [\n, [2283527], \n], \n, [2022-07-01T07:2...
# 1                                                 []
#
#                                                   2   \
# 0  [\n, [\n, [2283526], \n], \n, [2022-07-01T07:2...
# 1                                                 []
#
#                                                   3   \
# 0  [\n, [\n, [2283525], \n], \n, [2022-07-01T07:2...
# 1                                                 []
#
#                                                   4   \
# 0  [\n, [\n, [2283524], \n], \n, [2022-07-01T07:2...
# 1                  [\n, [\ne01c20aa7380\n], \n...\n]
#
#                                                   5   \
# 0  [\n, [\n, [2283523], \n], \n, [2022-07-01T07:1...
# ...

# %%
df.to_csv("Bitcoin.csv")
